# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import imp

# Import API key
temp_file = imp.load_source("gkey", "../Project1/gkey.py")

gkey = temp_file.gkey

del temp_file

# %%
# Create lists for append
Name = []
Address = []
Zip_Code = []
Lat = []
Lng = []

# %%
# Build URL
params = {"key": gkey,
          "radius": 50000,
         "location": "38.627003, -90.199402",
         "keyword": "grocery",  
             }

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

stl_grocery = requests.get(base_url, params=params)

stl_grocery = stl_grocery.json()

    
    
    
# Call and Append Data from API
for x in range(0,20):
    
        Name.append(stl_grocery["results"][x]["name"])
        Address.append(stl_grocery["results"][x]["vicinity"])
        Lat.append(stl_grocery["results"][x]["geometry"]["location"]["lat"])
        Lng.append(stl_grocery["results"][x]["geometry"]["location"]["lng"])
        
# Capture PageToken for Next Page        
        ptoken = stl_grocery["next_page_token"]

# %%
# Page 2
params = {"key": gkey,
          "radius": 50000,
         "location": "38.627003, -90.199402",
         "keyword": "grocery",
        "pagetoken": f"{ptoken}"
             }

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

stl_grocery = requests.get(base_url, params=params)

stl_grocery = stl_grocery.json()

    
    
    

for x in range(0,20):
    
        Name.append(stl_grocery["results"][x]["name"])
        Address.append(stl_grocery["results"][x]["vicinity"])
        Lat.append(stl_grocery["results"][x]["geometry"]["location"]["lat"])
        Lng.append(stl_grocery["results"][x]["geometry"]["location"]["lng"])
        
        ptoken = stl_grocery["next_page_token"]

# %%
# Page 3
params = {"key": gkey,
          "radius": 50000,
         "location": "38.627003, -90.199402",
         "keyword": "grocery",
        "pagetoken": f"{ptoken}"
             }

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

stl_grocery = requests.get(base_url, params=params)

stl_grocery = stl_grocery.json()

    
    
    

for x in range(0,20):
    
        Name.append(stl_grocery["results"][x]["name"])
        Address.append(stl_grocery["results"][x]["vicinity"])
        Lat.append(stl_grocery["results"][x]["geometry"]["location"]["lat"])
        Lng.append(stl_grocery["results"][x]["geometry"]["location"]["lng"])

# %%
# Create DataFrame
dic = {
    "Name":Name,
    "Address":Address,
    "Lat":Lat,
    "Lng":Lng
}
supermarket_df = pd.DataFrame(dic)
supermarket_df.head(100)
# Out:
#                                        Name  \
# 0                          Schnucks Arsenal
# 1                          Schnucks Lindell
# 2                              Fields Foods
# 3                                  Straub's
# 4                    Schnucks Richmond Ctr.
# 5      Dierbergs Markets - Brentwood Pointe
# 6                       Schnucks South City
# 7                                Save-A-Lot
# 8                        Schnucks Culinaria
# 9                        Whole Foods Market
# 10                      Schnucks Lindenwood
# 11                    Schnucks Chesterfield
# 12                             Trader Joe's
# 13                 Schnucks University City
# 14                               Save-A-Lot
# 15                                     ALDI
# 16         Dierbergs Markets - Market Place
# 17               Local Harvest Grocery, LLC
# 18                            County Market
# 19       Dierbergs Markets - Heritage Place
# 20                           Schnucks Ladue
# 21                    Schnucks Hampton Vlg.
# 22                      Schnucks Mid Rivers
# 23                               Save-A-Lot
# 24                    Freeburg Country Mart
# 25                     Schnucks Creve Coeur
# 26                    Schnucks Loughborough
# 27               Fresh Thyme Farmers Market
# 28                           Schnucks Mason
# 29                                     ALDI
# 30                               Save-A-Lot
# 31  Dierbergs Markets - Deer Creek Crossing
# 32                             Trader Joe's
# 33                      Global Foods Market
# 34      Dierbergs Markets - Fenton Crossing
# 35                              Ruler Foods
# 36                           Schwan Food Co
# 37                           Schwan Food Co
# 38                           Gustine Market
# 39                        2021 Zumbehl Rd, St Charles  38.782658 -90.534532
# 40  1160 Town and Country Crossing Dr, Town and Co...  38.622174 -90.515479
# 41               48 Brentwood Promenade Ct, Brentwood  38.627333 -90.341231
# 42               6569 N Illinois St, Fairview Heights  38.594282 -89.987476
# 43                          4200 Shaw Blvd, St. Louis  38.616166 -90.253785
# 44                        6601 Gravois Ave, St. Louis  38.572962 -90.282629
# 45                        13414 Clayton Rd, St. Louis  38.626954 -90.481113
# 46                   1601 S Brentwood Blvd, Brentwood  38.627109 -90.347884
# 47                       1018 N Kirkwood Rd, Kirkwood  38.599347 -90.405972
# 48                   302 Kingshighway Blvd, St. Louis  38.645454 -90.264367
# 49                  625 Lincoln Hwy, Fairview Heights  38.594093 -89.976199
# 50                      11505 Olive Blvd, Creve Coeur  38.671954 -90.436420
# 51                       317 Hawthorn Ave, St Charles  38.795291 -90.498129
# 52                         2222 Troy Rd, Edwardsville  38.785914 -89.948622
# 53                 211 W Lockwood Ave, Webster Groves  38.593724 -90.361990
# 54                   12420 Tesson Ferry Rd, St. Louis  38.508672 -90.374226
# 55                           5139 Shaw Ave, St. Louis  38.617977 -90.271957
# 56                              21 Adams St, Ferguson  38.742224 -90.303019
# 57                       9920 Lin Ferry Dr, St. Louis  38.523845 -90.352297
# 58                       2610 Telegraph Rd, St. Louis  38.511917 -90.290347
# 59                        335 N Euclid Ave, St. Louis  38.645735 -90.261663

# %%
# Add Zip Code
supermarket_df['Zip Code'] = ""
supermarket_df.head()
# Out:
#                      Name                                            Address  \
# 0        Schnucks Arsenal                            5055 Arsenal, St. Louis
# 1        Schnucks Lindell                       4171 Lindell Blvd, St. Louis
# 2            Fields Foods                      1500 Lafayette Ave, St. Louis
# 3                Straub's                         8282 Forsyth Blvd, Clayton
# 4  Schnucks Richmond Ctr.  SCHNUCKS RICHMOND CTR., 6600 Clayton Rd, St. L...
#
#          Lat        Lng Zip Code
# 0  38.606803 -90.273927
# 1  38.641805 -90.247256
# 2  38.612256 -90.209282
# 3  38.652284 -90.344205
# 4  38.633430 -90.314668

# %%
# Build URL to Call Google Maps for Zip Codes
params = {"key": gkey}

# Loop through each store location
for index, row in supermarket_df.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    lat = row["Lat"]
    lng = row["Lng"]

    params["latlng"] = f"{lat},{lng}"

    # make request
    supermarket_zip = requests.get(base_url, params=params)
    
    # convert to json
    supermarket_zip = supermarket_zip.json()
    
# Pull Zip Codes

    supermarket_df.loc[index, "Zip Code"] = supermarket_zip["results"][0]["address_components"][6]["long_name"]
    if supermarket_df.loc[index, "Zip Code"] == "United States":
        supermarket_df.loc[index, "Zip Code"] = supermarket_zip["results"][0]["address_components"][7]["long_name"]
    elif supermarket_df.loc[index, "Zip Code"] == "Missouri":
        supermarket_df.loc[index, "Zip Code"] = supermarket_zip["results"][0]["address_components"][8]["long_name"]


supermarket_df.head(60)
# Out:
#                                        Name  \
# 0                          Schnucks Arsenal
# 1                          Schnucks Lindell
# 2                              Fields Foods
# 3                                  Straub's
# 4                    Schnucks Richmond Ctr.
# 5      Dierbergs Markets - Brentwood Pointe
# 6                       Schnucks South City
# 7                                Save-A-Lot
# 8                        Schnucks Culinaria
# 9                        Whole Foods Market
# 25                        10650 Olive Blvd, St. Louis  38.672404 -90.414138
# 26                   1020 Loughborough Ave, St. Louis  38.556572 -90.262913
# 27                               2235 Hwy K, O'Fallon  38.779489 -90.702926
# 28                        12756 Olive Blvd, St. Louis  38.678249 -90.473114
# 29                       3721 S Grand Blvd, St. Louis  38.589514 -90.244800
# 30                      5437 Southwest Ave, St. Louis  38.610537 -90.279712
# 31                         2979 State Hwy K, O'Fallon  38.758288 -90.703763
# 32                     1679 Clarkson Rd, Chesterfield  38.644897 -90.566556
# 33                        421 N Kirkwood Rd, Kirkwood  38.585224 -90.406959
# 34                     450 Old Smizer Mill Rd, Fenton  38.513345 -90.450225
# 35                       2700 S Grand Blvd, St. Louis  38.607215 -90.240602
# 36                             704 W 8th St, Staunton  39.003821 -89.794036
# 37                       800 W McAllister St, Lebanon  38.593396 -89.823625
# 38                        3150 Gustine Ave, St. Louis  38.602007 -90.249590
# 39                        2021 Zumbehl Rd, St Charles  38.782658 -90.534532
# 40  1160 Town and Country Crossing Dr, Town and Co...  38.622174 -90.515479
# 41               48 Brentwood Promenade Ct, Brentwood  38.627333 -90.341231
# 42               6569 N Illinois St, Fairview Heights  38.594282 -89.987476
# 43                          4200 Shaw Blvd, St. Louis  38.616166 -90.253785
# 44                        6601 Gravois Ave, St. Louis  38.572962 -90.282629
# 45                        13414 Clayton Rd, St. Louis  38.626954 -90.481113
# 46                   1601 S Brentwood Blvd, Brentwood  38.627109 -90.347884
# 47                       1018 N Kirkwood Rd, Kirkwood  38.599347 -90.405972
# 48                   302 Kingshighway Blvd, St. Louis  38.645454 -90.264367
# 49                  625 Lincoln Hwy, Fairview Heights  38.594093 -89.976199
# 50                      11505 Olive Blvd, Creve Coeur  38.671954 -90.436420
# 51                       317 Hawthorn Ave, St Charles  38.795291 -90.498129
# 52                         2222 Troy Rd, Edwardsville  38.785914 -89.948622
# 53                 211 W Lockwood Ave, Webster Groves  38.593724 -90.361990
# 54                   12420 Tesson Ferry Rd, St. Louis  38.508672 -90.374226
# 55                           5139 Shaw Ave, St. Louis  38.617977 -90.271957
# 56                              21 Adams St, Ferguson  38.742224 -90.303019
# 57                       9920 Lin Ferry Dr, St. Louis  38.523845 -90.352297
# 58                       2610 Telegraph Rd, St. Louis  38.511917 -90.290347
# 59                        335 N Euclid Ave, St. Louis  38.645735 -90.261663
#
#    Zip Code
# 0     63139
# 1     63108
# 2     63104
# 3     63105
# 4     63117
# 5     63144
# 6     63118
# 7     63104
# 8     63101
# 9     63108
# 10    63301
# 11    63017
# 12    63131
# 13    63130
# 14    63118
# 15    63108
# 16    63017
# 17    63116
# 18    63389
# 19    63141
# 20    63124
# 21    63109
# 22    63376
# 23    63113
# 24    62243
# 25    63141
# 26    63111
# 27    63368
# 28    63141
# 29    63118
# 30    63139
# 31    63368
# 32    63017
# 33    63122
# 34    63026
# 35    63118
# 36    62088
# 37    62254
# 38    63116
# 39    63303
# 40    63017
# 41    63144
# 42    62208
# 43    63110
# 44    63116
# 45    63131
# 46    63144
# 47    63122
# 48    63108
# 49    62208
# 50    63141
# 51    63301
# 52    62025
# 53    63119
# 54    63128
# 55    63110
# 56    63135
# 57    63123
# 58    63125
# 59    63108

# %%
output_data_file = "grocery.csv"
supermarket_df.to_csv(output_data_file, index=False, header=True)
